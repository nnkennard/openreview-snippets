# %% [markdown]
# # Get manuscript 'timeline'
#
# ## Description
# Given an OpenReview invitation, list the events (submissions, revisions, reviews, comments, etc.) associated with each submission, arranged chronologically.
#
# ## Notes
# * I am not sure what the difference is between `cdate`, `tcdate` and other timestamps. I will check with OpenReview folks to confirm that I am using the correct field.
# * The list of events does not include comment edits, including score changes. I do not think these are available, but I can double check with OpenReview folks on this too.
# * I haven't done any of the work to print this into a nice csv or anything, but I think it should be straightforward. You can use `event.stringify(pretty=False)` if you would prefer raw timestamps instead of human readable.

# %%
import collections
from datetime import datetime
import openreview
import os

# Change these values according to your needs
INVITATION = 'ICLR.cc/2018/Conference/-/Blind_Submission'
LIMIT = 10 # Number of papers to download all revisions for

# A client is required for any OpenReview API actions
guest_client = openreview.Client(baseurl='https://api.openreview.net')

# %%
class EventType(object):
    SUBMISSION = "Submission"
    REVISION = "Revision"
    REVIEW = "Review"
    COMMENT = "Comment"
    METAREVIEW = "Metareview"
    
GENERIC_INITIATOR_AUTHORS = "Authors"

def get_initiator(note):
    return note.signatures[0].split("/")[-1]

def clean_timestamp(timestamp):
    return datetime.fromtimestamp(
        timestamp/1000).strftime('%Y-%m-%dT%H:%M:%S') # Something human-readable for the file name

class Event(object):
    def __init__(self, forum, event_type, initiator, identifier, timestamp, reply_to):
        self.forum = forum
        self.event_type = event_type
        self.initiator = initiator
        self.identifier = identifier
        self.timestamp = timestamp
        self.reply_to = reply_to
    
    def stringify(self, pretty=True):
        if pretty:
            timestamp = clean_timestamp(self.timestamp)
        else:
            timestamp = self.timestamp
        return "\t".join(str(i) for i in [
            timestamp, self.forum, self.event_type,
            self.initiator, self.identifier, self.reply_to])

def get_events_from_forum(forum_note):
    events = []
    for revision in guest_client.get_references(
            referent=forum_note.id, original=True):
        events.append(Event(
            forum_note.id, EventType.REVISION, GENERIC_INITIATOR_AUTHORS,
            revision.id, revision.tcdate, revision.replyto))
  
    this_forum_notes = guest_client.get_notes(forum=forum_note.id)
    for note in this_forum_notes:
        initiator = get_initiator(note)
        
        if 'TL;DR' in note.content: # Find a better test for this!
            event_type = EventType.SUBMISSION
        elif 'review' in note.content:
            event_type = EventType.REVIEW
        elif 'metareview' in note.content:
            event_type = EventType.METAREVIEW
        else:
            event_type = EventType.COMMENT
        events.append(Event(
            forum_note.id, event_type, initiator,
            note.id, note.tcdate, note.replyto))
    return list(sorted(events, key=lambda x:x.timestamp))

# %%
for i, forum_note in enumerate(openreview.tools.iterget_notes(
        guest_client, invitation=INVITATION)):
    
    print( "#" + forum_note.content["title"] + "\n")
    for event in get_events_from_forum(forum_note):
        print(event.stringify())
    print("\n")
    
    if i == LIMIT:
        break
# Out:
# #Parameter Space Noise for Exploration
#
# 2017-10-27T09:12:44	ByBAl2eAZ	Revision	Authors	SJB0xhgCZ	None
# 2017-10-27T09:12:45	ByBAl2eAZ	Submission	Conference	ByBAl2eAZ	None
# 2017-11-09T01:16:01	ByBAl2eAZ	Review	AnonReviewer3	By9jfdZkM	ByBAl2eAZ
# 2017-11-15T13:07:32	ByBAl2eAZ	Comment	Area_Chair	rkaPGW5JM	rk940apAW
# 2017-11-26T14:59:52	ByBAl2eAZ	Review	AnonReviewer2	r1gBpq_gG	ByBAl2eAZ
# 2017-11-27T06:52:12	ByBAl2eAZ	Review	AnonReviewer1	ryVd3dFgf	ByBAl2eAZ
# 2017-12-15T01:21:24	ByBAl2eAZ	Comment	Authors	SkaJ5JWMG	ryVd3dFgf
# 2017-12-15T01:22:26	ByBAl2eAZ	Comment	Authors	ByiX9J-zf	r1gBpq_gG
# 2017-12-15T01:23:09	ByBAl2eAZ	Comment	Authors	HJUU9kZzf	By9jfdZkM
# 2018-01-03T07:27:02	ByBAl2eAZ	Revision	Authors	ByyQ3S5mz	None
# 2018-01-03T07:28:35	ByBAl2eAZ	Comment	Authors	HJjO3r97f	ByBAl2eAZ
# 2018-01-05T20:50:54	ByBAl2eAZ	Comment	(anonymous)	HyUtjoTmG	ByBAl2eAZ
# 2018-01-08T05:59:03	ByBAl2eAZ	Comment	Authors	HJxWJ0eEG	HyUtjoTmG
# 2018-01-12T13:33:12	ByBAl2eAZ	Comment	AnonReviewer2	S1Zd1FUEM	ByiX9J-zf
# 2018-01-29T13:12:11	ByBAl2eAZ	Comment	Program_Chairs	H1EWEkpBf	ByBAl2eAZ
# 2018-01-31T03:48:21	ByBAl2eAZ	Revision	Authors	rypRMbJ8M	None
# 2022-02-10T06:29:50	ByBAl2eAZ	Revision	Authors	HeW8EPdzJq	None
# 2022-03-15T17:15:41	ByBAl2eAZ	Revision	Authors	BcS-MKCb5	None
#
#
# #GraphVAE: Towards Generation of Small Graphs Using Variational Autoencoders
#
# 2017-10-27T16:31:35	SJlhPMWAW	Revision	Authors	r1Jhwf-RZ	None
# 2017-10-27T16:31:35	SJlhPMWAW	Submission	Conference	SJlhPMWAW	None
# 2017-10-27T16:52:28	SJlhPMWAW	Revision	Authors	ByNqnfWRZ	None
# 2017-11-25T02:53:13	SJlhPMWAW	Review	AnonReviewer1	rJZdWiUxz	SJlhPMWAW
# 2017-12-01T11:31:26	SJlhPMWAW	Review	AnonReviewer2	ByvkN-k-G	SJlhPMWAW
# 2017-12-02T02:51:09	SJlhPMWAW	Comment	(anonymous)	BkVdoCJZG	SJlhPMWAW
# 2017-12-04T00:54:08	SJlhPMWAW	Review	AnonReviewer3	B1ubmvfZM	SJlhPMWAW
# 2017-12-23T12:58:43	SJlhPMWAW	Revision	Authors	r1sUFGhGG	None
# 2017-12-23T13:03:19	SJlhPMWAW	Comment	Authors	Hk1_cfnzf	rJZdWiUxz
# 2017-12-23T13:06:09	SJlhPMWAW	Comment	Authors	H1KfiM3MM	ByvkN-k-G
# 2017-12-23T13:07:19	SJlhPMWAW	Comment	Authors	H1lPszhMM	BkVdoCJZG
# 2017-12-23T13:10:29	SJlhPMWAW	Comment	Authors	Hypz2G3Gz	B1ubmvfZM
# 2018-02-23T04:34:49	rJXMpikCZ	Revision	Authors	ry-BlD6DM	None
# 2022-02-10T06:29:23	rJXMpikCZ	Revision	Authors	B8X3GwOGy9	None
# 2022-03-11T01:44:23	rJXMpikCZ	Revision	Authors	H34J0yOuZc	None
#
#
# #Expressive power of recurrent neural networks
#
# 2017-10-27T15:40:56	S1WRibb0Z	Revision	Authors	rkxAibZAb	None
# 2017-10-27T15:40:57	S1WRibb0Z	Submission	Conference	S1WRibb0Z	None
# 2017-10-27T16:00:44	S1WRibb0Z	Revision	Authors	Byrugz-CW	None
# 2017-10-29T10:49:27	S1WRibb0Z	Revision	Authors	rk1FcwXAW	None
# 2017-11-25T01:54:04	S1WRibb0Z	Review	AnonReviewer2	SJr9X58lz	S1WRibb0Z
# 2017-11-25T10:21:39	S1WRibb0Z	Review	AnonReviewer1	HyjYq-DgM	S1WRibb0Z
# 2017-11-29T00:57:12	S1WRibb0Z	Review	AnonReviewer3	ryxBhTjgM	S1WRibb0Z
# 2018-01-02T10:06:59	S1WRibb0Z	Revision	Authors	r1nfx7FQz	None
# 2018-01-02T10:06:59	S1WRibb0Z	Revision	Authors	S1hMemFQG	None
# 2018-01-02T10:11:39	S1WRibb0Z	Comment	Authors	rk4NWQt7M	S1WRibb0Z
# 2018-01-02T10:16:42	S1WRibb0Z	Comment	Authors	r17DGXtXf	ryxBhTjgM
# 2018-01-02T10:19:29	S1WRibb0Z	Comment	Authors	S1KW7QFQG	HyjYq-DgM
# 2018-01-02T10:22:48	S1WRibb0Z	Comment	Authors	HJgCQmtQG	SJr9X58lz
# 2018-01-29T13:12:07	S1WRibb0Z	Comment	Program_Chairs	r1kWEJTHM	S1WRibb0Z
# 2018-02-07T08:24:11	S1WRibb0Z	Revision	Authors	H1XW0uuUz	None
# 2022-02-10T06:29:19	S1WRibb0Z	Revision	Authors	Sl-OzDOMyc	None
# 2022-03-09T01:25:02	S1WRibb0Z	Revision	Authors	SNeLr_pHW9	None
#
#
# #META LEARNING SHARED HIERARCHIES
#
# 2017-10-27T14:11:22	SyX0IeWAW	Revision	Authors	BJ7RLgWRZ	None
# 2017-10-27T14:11:23	SyX0IeWAW	Submission	Conference	SyX0IeWAW	None
# 2017-11-27T11:41:15	SyX0IeWAW	Review	AnonReviewer1	BJN4gTtlM	SyX0IeWAW
# 2017-11-27T11:55:47	SyX0IeWAW	Comment	AnonReviewer2	r13qQpKxM	SyX0IeWAW
# 2017-11-27T12:03:35	SyX0IeWAW	Review	AnonReviewer2	HyJuHTteM	SyX0IeWAW
# 2017-11-27T19:37:42	SyX0IeWAW	Review	AnonReviewer3	r1RR1Vclf	SyX0IeWAW
# 2017-11-29T13:35:50	SyX0IeWAW	Comment	(anonymous)	rkCZR_3xz	SyX0IeWAW
# 2017-12-01T16:38:13	SyX0IeWAW	Comment	Authors	ByaasHJWM	rkCZR_3xz
# 2017-12-01T16:42:24	SyX0IeWAW	Comment	Authors	S1YphBy-f	r13qQpKxM
# 2017-12-12T01:46:20	SyX0IeWAW	Revision	Authors	S1HHslTWf	None
# 2017-12-12T01:48:41	SyX0IeWAW	Comment	Authors	rJG0slabf	r1RR1Vclf
# 2017-12-12T01:50:43	SyX0IeWAW	Comment	Authors	r1nH2xp-f	HyJuHTteM
# 2017-12-12T01:52:12	SyX0IeWAW	Comment	Authors	BJBohe6bz	BJN4gTtlM
# 2017-12-12T01:53:57	SyX0IeWAW	Comment	Authors	ByaWalTbf	S1YphBy-f
# 2017-12-12T02:42:12	SyX0IeWAW	Comment	AnonReviewer2	Hy28ObpbM	ByaWalTbf
# 2017-12-13T23:32:29	SyX0IeWAW	Comment	Authors	S1BykK1Mz	Hy28ObpbM
# 2017-12-15T03:34:39	SyX0IeWAW	Comment	(anonymous)	HkdQtbZfM	SyX0IeWAW
# 2017-12-16T15:13:09	SyX0IeWAW	Comment	Authors	ByaUAxmMz	HkdQtbZfM
# 2018-01-04T22:11:34	SyX0IeWAW	Revision	Authors	HJyepwn7G	None
# 2018-01-04T22:17:14	SyX0IeWAW	Comment	Authors	rJMH0whmz	SyX0IeWAW
# 2018-01-29T13:07:41	SyX0IeWAW	Comment	Program_Chairs	rJrxmkTHf	SyX0IeWAW
# 2018-02-23T00:38:26	SyX0IeWAW	Revision	Authors	HyqCOmawz	None
# 2022-02-10T06:30:44	SyX0IeWAW	Revision	Authors	re6vDuM1q	None
# 2022-03-07T02:30:38	SyX0IeWAW	Revision	Authors	B5wiEVm-c	None
# 2022-03-07T06:26:47	SyX0IeWAW	Revision	Authors	SKbe-hDmb9	None
#
#
# #Mixed Precision Training
#
# 2017-10-26T19:07:03	r1gs9JgRZ	Revision	Authors	H1kjqyxCZ	None
# 2017-10-26T19:07:04	r1gs9JgRZ	Comment	Conference	r1gs9JgRZ	None
# 2017-10-26T19:09:15	r1gs9JgRZ	Revision	Authors	BJX7iJxRW	None
# 2017-11-26T02:37:02	r1gs9JgRZ	Review	AnonReviewer1	rJwXkeOgM	r1gs9JgRZ
# 2017-11-27T16:13:48	r1gs9JgRZ	Review	AnonReviewer3	SkSMlWcgG	r1gs9JgRZ
# 2017-11-29T16:07:55	r1gs9JgRZ	Review	AnonReviewer2	SJQ3bonlG	r1gs9JgRZ
# 2017-12-07T20:48:39	r1gs9JgRZ	Comment	~Stephen_Merity1	SyetJ_Pbz	SkSMlWcgG
# 2018-01-04T22:36:35	r1gs9JgRZ	Comment	Authors	S1nTzd2Qf	SJQ3bonlG
# 2018-01-04T22:38:42	r1gs9JgRZ	Comment	Authors	ryjSm_hQz	SkSMlWcgG
# 2018-01-04T22:41:23	r1gs9JgRZ	Comment	Authors	SyoJNu2Xf	SyetJ_Pbz
# 2018-01-04T22:43:33	r1gs9JgRZ	Comment	Authors	SyCvNOnQf	rJwXkeOgM
# 2018-01-05T16:22:38	r1gs9JgRZ	Revision	Authors	S1vj3wpXz	None
# 2018-01-05T16:25:36	r1gs9JgRZ	Comment	Authors	rktIavaQz	r1gs9JgRZ
# 2018-01-05T16:52:25	r1gs9JgRZ	Revision	Authors	BkfimdTQf	None
# 2018-01-29T13:07:33	r1gs9JgRZ	Comment	Program_Chairs	rJAJQ1prf	r1gs9JgRZ
# 2018-02-15T14:18:13	r1gs9JgRZ	Revision	Authors	r1ag6UmPz	None
# 2022-02-10T06:29:04	r1gs9JgRZ	Revision	Authors	S3EYbvOGJ5	None
# 2022-03-06T21:41:56	r1gs9JgRZ	Revision	Authors	B3EhgWgXWq	None
#
#
# #Learning to Represent Programs with Graphs
#
# 2017-10-27T10:36:46	BJOFETxR-	Revision	Authors	H1Ut46lRb	None
# 2017-10-27T10:36:48	BJOFETxR-	Submission	Conference	BJOFETxR-	None
# 2017-11-27T20:35:43	BJOFETxR-	Review	AnonReviewer2	ryuuTE9gG	BJOFETxR-
# 2017-11-30T03:55:16	BJOFETxR-	Review	AnonReviewer3	rkhdDBalz	BJOFETxR-
# 2017-12-02T00:16:35	BJOFETxR-	Review	AnonReviewer1	H1oEvnkWM	BJOFETxR-
# 2017-12-04T10:46:44	BJOFETxR-	Comment	(anonymous)	Hy3kAkmZM	BJOFETxR-
# 2017-12-05T08:41:28	BJOFETxR-	Comment	Authors	Hy-fzXEZM	Hy3kAkmZM
# 2017-12-06T13:28:03	BJOFETxR-	Revision	Authors	BkinLnSWz	None
# 2017-12-06T13:30:19	BJOFETxR-	Comment	Authors	BJNSv3SWf	BJOFETxR-
# 2017-12-06T13:31:34	BJOFETxR-	Comment	Authors	SkRKw2SWz	H1oEvnkWM
# 2017-12-06T13:32:02	BJOFETxR-	Comment	Authors	B1ioD3SZG	rkhdDBalz
# 2017-12-06T13:32:45	BJOFETxR-	Comment	Authors	S1SRPhSbM	ryuuTE9gG
# 2017-12-06T18:07:25	BJOFETxR-	Comment	(anonymous)	H1UNdg8-G	Hy-fzXEZM
# 2017-12-11T06:24:51	BJOFETxR-	Comment	Authors	Hy2ZoJhbf	H1UNdg8-G
# 2017-12-11T06:26:05	BJOFETxR-	Comment	Authors	B1LIjy2Zz	H1UNdg8-G
# 2018-01-05T09:15:23	BJOFETxR-	Comment	Authors	SyXFuWT7M	BJNSv3SWf
# 2018-01-29T13:06:33	BJOFETxR-	Comment	Program_Chairs	S1znzJ6rz	BJOFETxR-
# 2018-02-22T05:11:50	BJOFETxR-	Revision	Authors	SJ0DvzhPM	None
# 2018-02-22T06:50:50	BJOFETxR-	Revision	Authors	r1Xs07nwz	None
# 2018-02-22T06:58:17	BJOFETxR-	Revision	Authors	ryZwxV2Dz	None
# 2018-05-04T16:19:37	BJOFETxR-	Revision	Authors	HJ-vxBqTf	None
# 2022-02-10T06:27:16	BJOFETxR-	Revision	Authors	BTMpcUuzJ5	None
# 2022-03-04T09:26:46	BJOFETxR-	Revision	Authors	ru-1hbskb9	None
